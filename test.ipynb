# %%
from custom_functions.face_embedding import *
from retinaface import RetinaFace
import tensorflow as tf
import json 
import cv2

# %%
query_folder_path = 'queries/query1'
# read configuration
json_file_path = 'configurations/config.json'
# read from a json file
with open(json_file_path, 'r') as json_file:
    configuration = json.load(json_file)

# %%
files_list = list_files_in_directory(query_folder_path)
files_list
# Out:
# ['query0.jpg', 'query1.jpg', 'query2.jpg', 'query3.jpg']

# %%
face_model = tf.keras.models.load_model(configuration['ghostfacenets_model_path'], compile=False)

# %%
query_embeddings = generate_query_embeddings(query_folder_path, face_model)

# %%
find_cosine_distance(query_embeddings[1],query_embeddings[0])
# Out:
# 0.7690447866916656

# %%
img = cv2.imread('query0.jpg')

# %%
generate_embeddings_img(img, face_model)

# %%
import tensorflow as tf

# Check if GPU is available
print("Num GPUs Available: ", )
# Out:
# Num GPUs Available:  0

# %%
import tensorflow as tf

# Set GPU devices
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    # Limit GPU memory growth (optional)
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

    # Set visible GPUs
    tf.config.experimental.set_visible_devices(gpus, 'GPU')

# %%
# Out:
# 0

# %%
print(f"Num GPUs Available for Tensorflow models: {len(tf.config.experimental.list_physical_devices('GPU'))}")
# Out:
# Num GPUs Available for Tensorflow models: 0

# %%
boxes = [[1,2,3,4],[1,2,3,4]]
for i, box in enumerate(boxes):
    print(box)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
import matplotlib.pyplot as plt
faces = RetinaFace.extract_faces(img, align = True)

# %%
for face in faces:
  plt.imshow(face)
  plt.show()

# %%
lst = [1,2,42,5,7,75]
lst = list(lst)
index = lst.index(42)
index
# Out:
# 2

# %%
def my_func(a,b):
    return a+b

# %%
import concurrent.futures
# from func_collection import my_func

def run_my_func(a, b):
    try:
        return my_func(a, b)
    except Exception as e:
        print(f"Error in worker process: {e}")
        raise

# Create a ProcessPoolExecutor
with concurrent.futures.ProcessPoolExecutor() as executor:
    # Submit the task to the executor
    future = executor.submit(run_my_func, 1, 2)

    try:
        # Wait for the task to complete and get the result
        output = future.result()
    except concurrent.futures.process.BrokenProcessPool as e:
        print(f"BrokenProcessPool error: {e}")
        # Handle the error as needed
